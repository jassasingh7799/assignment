# %%
from numpy import random 
x=random.normal(size=(2,3))
print(x)
# Out:
# [[-1.14186274  0.07914203  1.32470754]
#  [ 0.23304306 -1.06090044 -0.21798377]]

# %%
from numpy import random
x=random.normal(loc=1,scale=2,size=(2,3))
print(x)
# Out:
# [[0.72669564 1.96875609 3.71446476]
#  [0.87121725 0.46620632 0.43522427]]

# %%
#visualization of normal distribution

from numpy import random 
import matplotlib.pyplot as plt
import seaborn as sns

x=random.normal(size=(2,3))
sns.distplot(x,hist=False)
plt.show()
# Out:
# C:\Users\jasme\AppData\Local\Temp\ipykernel_2972\2370646287.py:8: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x,hist=False)
